# %%
import torchvision
from torchvision import  transforms
import torch 
import torch.nn as nn
import torch.optim as optim
from shared.models import *
from shared.dataloaders import *
from knowledge_distilation.knowledge_distilation import *
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# student_model  = smallVGG().to(device)
# train_model(student_model,10,trainloader,device=device)
# test_model_accuracy(student_model,testloader,device=device)

# %%
# test_model_accuracy(student_model,testloader,device=device)

# %%
# teacher_model  = myVGG().to(device)
# train_model(teacher_model,10,trainloader,device=device)

# %%
teacher_model  = myVGG().to(device)

# %%
# test_model_accuracy(teacher_model,testloader,device=device)

# %%
distilled_model =  smallVGG().to(device)
knowledge_distillation(teacher_model, distilled_model,n_epochs=1, trainloader=trainloader,device=device)
# Out:
# Training Loss: 0.0001
# Training Loss: 0.0091
# Training Loss: 0.0124
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 distilled_model =  smallVGG().to(device)
# ----> 2 knowledge_distillation(teacher_model, distilled_model,n_epochs=1, trainloader=trainloader,device=device)
#
# File c:\Users\paral\Desktop\work\edge computing\implementations\NeuralNetworkCompressionMethods\knowledge_distilation\knowledge_distilation.py:29, in knowledge_distillation(teacher_model, student_model, n_epochs, trainloader, temperature, optimizer, criterion, device)
#      27 outputs = student_model(inputs)  # Forward pass
#      28 loss = criterion(outputs, targets)  # Compute loss
# ---> 29 loss.backward()  # Backward pass
#      30 optimizer.step()  # Update weights
#      31 running_loss += loss.item() * inputs.size(0)
#
# File c:\Users\paral\Desktop\work\edge computing\implementations\NeuralNetworkCompressionMethods\venv\Lib\site-packages\torch\_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File c:\Users\paral\Desktop\work\edge computing\implementations\NeuralNetworkCompressionMethods\venv\Lib\site-packages\torch\autograd\__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %%
test_model_accuracy(distilled_model,testloader,device=device)
# Out:
# Accuracy of the model on the test images: 56.67%
# 56.67
