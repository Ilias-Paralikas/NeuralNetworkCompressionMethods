# %%
import torch
import torchvision
from torchvision import  models
from pruning.pruning_functions import *
from shared.dataloaders import *
from shared.models import *
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
EPOCHS =1
PRUNING_RATE = 0.3

# %%
model = myVGG().to(device)
shape = next(iter(trainloader))[0].shape
prune_model(model,PRUNING_RATE,shape,device=device)
train_model(model,n_epochs=EPOCHS,trainloader=trainloader)
# Out:
# [2024-05-30 16:02:10] Start to speedup the model...
# [2024-05-30 16:02:10] Resolve the mask conflict before mask propagate...
# [2024-05-30 16:02:10] dim0 sparsity: 0.296875
# [2024-05-30 16:02:10] dim1 sparsity: 0.000000
# 0 Filter
# [2024-05-30 16:02:10] dim0 sparsity: 0.296875
# [2024-05-30 16:02:10] dim1 sparsity: 0.000000
# [2024-05-30 16:02:10] Infer module masks...
# [2024-05-30 16:02:10] Propagate original variables
# [2024-05-30 16:02:10] Propagate variables for placeholder: x, output mask:  0.0000
# [2024-05-30 16:02:10] Propagate variables for call_module: net_0_0, weight:  0.2969 bias:  0.2969 , output mask:  0.0000
# [2024-05-30 16:02:10] Propagate variables for call_module: net_0_1, , output mask:  0.0000
# [2024-05-30 16:02:10] Propagate variables for call_module: net_0_2, , output mask:  0.0000
# [2024-05-30 16:02:10] Propagate variables for call_module: net_1_0, weight:  0.2969 bias:  0.2969 , output mask:  0.0000
# [2024-05-30 16:02:10] Propagate variables for call_module: net_1_1, , output mask:  0.0000
# [2024-05-30 16:02:10] Propagate variables for call_module: net_1_2, , output mask:  0.0000
# [2024-05-30 16:02:10] Propagate variables for call_module: net_2_0, weight:  0.2969 bias:  0.2969 , output mask:  0.0000
# [2024-05-30 16:02:10] Propagate variables for call_module: net_2_1, , output mask:  0.0000
# [2024-05-30 16:02:10] Propagate variables for call_module: net_2_2, , output mask:  0.0000
# [2024-05-30 16:02:10] Propagate variables for call_module: net_3_0, weight:  0.2969 bias:  0.2969 , output mask:  0.0000
# [2024-05-30 16:02:10] Propagate variables for call_module: net_3_1, , output mask:  0.0000
# [2024-05-30 16:02:10] Propagate variables for call_module: net_3_2, , output mask:  0.0000
# [2024-05-30 16:02:10] Propagate variables for call_module: net_4_0, , output mask:  0.0000
# [2024-05-30 16:02:11] Propagate variables for call_module: net_4_1, weight:  0.2988 bias:  0.2988 , output mask:  0.0000
# [2024-05-30 16:02:11] Propagate variables for call_module: net_4_2, , output mask:  0.0000
# [2024-05-30 16:02:11] Propagate variables for call_module: net_4_3, weight:  0.2988 bias:  0.2988 , output mask:  0.0000
# [2024-05-30 16:02:11] Propagate variables for call_module: net_4_4, , output mask:  0.0000
# [2024-05-30 16:02:11] Propagate variables for call_module: net_4_5, , output mask:  0.0000
# [2024-05-30 16:02:11] Propagate variables for output: output, output mask:  0.0000
# [2024-05-30 16:02:11] Update direct sparsity...
# [2024-05-30 16:02:13] Update direct mask for placeholder: x, output mask:  0.0000
# [2024-05-30 16:02:13] Update direct mask for call_module: net_0_0, weight:  0.2969 bias:  0.2969 , output mask:  0.2969
# [2024-05-30 16:02:13] Update direct mask for call_module: net_0_1, , output mask:  0.2969
# [2024-05-30 16:02:13] Update direct mask for call_module: net_0_2, , output mask:  0.2969
# [2024-05-30 16:02:13] Update direct mask for call_module: net_1_0, weight:  0.2969 bias:  0.2969 , output mask:  0.2969
# [2024-05-30 16:02:13] Update direct mask for call_module: net_1_1, , output mask:  0.2969
# [2024-05-30 16:02:13] Update direct mask for call_module: net_1_2, , output mask:  0.2969
# [2024-05-30 16:02:13] Update direct mask for call_module: net_2_0, weight:  0.2969 bias:  0.2969 , output mask:  0.2969
# [2024-05-30 16:02:13] Update direct mask for call_module: net_2_1, , output mask:  0.2969
# [2024-05-30 16:02:13] Update direct mask for call_module: net_2_2, , output mask:  0.2969
# [2024-05-30 16:02:13] Update direct mask for call_module: net_3_0, weight:  0.2969 bias:  0.2969 , output mask:  0.2969
# [2024-05-30 16:02:13] Update direct mask for call_module: net_3_1, , output mask:  0.2969
# [2024-05-30 16:02:13] Update direct mask for call_module: net_3_2, , output mask:  0.2969
# [2024-05-30 16:02:13] Update direct mask for call_module: net_4_0, , output mask:  0.2969
# [2024-05-30 16:02:13] Update direct mask for call_module: net_4_1, weight:  0.2988 bias:  0.2988 , output mask:  0.2988
# [2024-05-30 16:02:13] Update direct mask for call_module: net_4_2, , output mask:  0.2988
# [2024-05-30 16:02:13] Update direct mask for call_module: net_4_3, weight:  0.2988 bias:  0.2988 , output mask:  0.2988
# [2024-05-30 16:02:13] Update direct mask for call_module: net_4_4, , output mask:  0.2988
# [2024-05-30 16:02:13] Update direct mask for call_module: net_4_5, , output mask:  0.0000
# [2024-05-30 16:02:13] Update direct mask for output: output, output mask:  0.0000
# [2024-05-30 16:02:13] Update indirect sparsity...
# [2024-05-30 16:02:13] Update indirect mask for output: output, output mask:  0.0000
# [2024-05-30 16:02:13] Update indirect mask for call_module: net_4_5, , output mask:  0.0000
# [2024-05-30 16:02:13] Update indirect mask for call_module: net_4_4, , output mask:  0.2988
# [2024-05-30 16:02:13] Update indirect mask for call_module: net_4_3, weight:  0.5084 bias:  0.2988 , output mask:  0.2988
# [2024-05-30 16:02:13] Update indirect mask for call_module: net_4_2, , output mask:  0.2988
# [2024-05-30 16:02:14] Update indirect mask for call_module: net_4_1, weight:  0.5070 bias:  0.2988 , output mask:  0.2988
# [2024-05-30 16:02:14] Update indirect mask for call_module: net_4_0, , output mask:  0.2969
# [2024-05-30 16:02:14] Update indirect mask for call_module: net_3_2, , output mask:  0.2969
# [2024-05-30 16:02:14] Update indirect mask for call_module: net_3_1, , output mask:  0.2969
# [2024-05-30 16:02:14] Update indirect mask for call_module: net_3_0, weight:  0.5056 bias:  0.2969 , output mask:  0.2969
# [2024-05-30 16:02:14] Update indirect mask for call_module: net_2_2, , output mask:  0.2969
# [2024-05-30 16:02:14] Update indirect mask for call_module: net_2_1, , output mask:  0.2969
# [2024-05-30 16:02:14] Update indirect mask for call_module: net_2_0, weight:  0.5056 bias:  0.2969 , output mask:  0.2969
# [2024-05-30 16:02:14] Update indirect mask for call_module: net_1_2, , output mask:  0.2969
# [2024-05-30 16:02:14] Update indirect mask for call_module: net_1_1, , output mask:  0.2969
# [2024-05-30 16:02:14] Update indirect mask for call_module: net_1_0, weight:  0.5056 bias:  0.2969 , output mask:  0.2969
# [2024-05-30 16:02:14] Update indirect mask for call_module: net_0_2, , output mask:  0.2969
# [2024-05-30 16:02:14] Update indirect mask for call_module: net_0_1, , output mask:  0.2969
# [2024-05-30 16:02:14] Update indirect mask for call_module: net_0_0, weight:  0.2969 bias:  0.2969 , output mask:  0.2969
# [2024-05-30 16:02:14] Update indirect mask for placeholder: x, output mask:  0.0000
# [2024-05-30 16:02:14] Resolve the mask conflict after mask propagate...
# [2024-05-30 16:02:14] dim0 sparsity: 0.296875
# [2024-05-30 16:02:14] dim1 sparsity: 0.293436
# [2024-05-30 16:02:14] WARNING: both dim0 and dim1 masks found.
# 0 Filter
# [2024-05-30 16:02:14] dim0 sparsity: 0.296875
# [2024-05-30 16:02:14] dim1 sparsity: 0.293436
# [2024-05-30 16:02:14] WARNING: both dim0 and dim1 masks found.
# [2024-05-30 16:02:15] Replace compressed modules...
# [2024-05-30 16:02:15] replace module (name: net_0_0, op_type: Conv2d)
# [2024-05-30 16:02:15] replace conv2d with in_channels: 3, out_channels: 45
# [2024-05-30 16:02:15] replace module (name: net_0_1, op_type: BatchNorm2d)
# [2024-05-30 16:02:15] replace batchnorm2d with num_features: 45
# [2024-05-30 16:02:15] replace module (name: net_0_2, op_type: ReLU)
# [2024-05-30 16:02:15] replace module (name: net_1_0, op_type: Conv2d)
# [2024-05-30 16:02:15] replace conv2d with in_channels: 45, out_channels: 45
# [2024-05-30 16:02:15] replace module (name: net_1_1, op_type: BatchNorm2d)
# [2024-05-30 16:02:15] replace batchnorm2d with num_features: 45
# [2024-05-30 16:02:15] replace module (name: net_1_2, op_type: ReLU)
# [2024-05-30 16:02:15] replace module (name: net_2_0, op_type: Conv2d)
# [2024-05-30 16:02:15] replace conv2d with in_channels: 45, out_channels: 90
# [2024-05-30 16:02:15] replace module (name: net_2_1, op_type: BatchNorm2d)
# [2024-05-30 16:02:15] replace batchnorm2d with num_features: 90
# [2024-05-30 16:02:15] replace module (name: net_2_2, op_type: ReLU)
# [2024-05-30 16:02:15] replace module (name: net_3_0, op_type: Conv2d)
# [2024-05-30 16:02:15] replace conv2d with in_channels: 90, out_channels: 90
# [2024-05-30 16:02:15] replace module (name: net_3_1, op_type: BatchNorm2d)
# [2024-05-30 16:02:15] replace batchnorm2d with num_features: 90
# [2024-05-30 16:02:15] replace module (name: net_3_2, op_type: ReLU)
# [2024-05-30 16:02:15] replace module (name: net_4_0, op_type: Flatten)
# [2024-05-30 16:02:15] replace module (name: net_4_1, op_type: Linear)
# [2024-05-30 16:02:15] replace linear with new in_features: 51840, out_features: 359
# [2024-05-30 16:02:15] replace module (name: net_4_2, op_type: ReLU)
# [2024-05-30 16:02:15] replace module (name: net_4_3, op_type: Linear)
# [2024-05-30 16:02:15] replace linear with new in_features: 359, out_features: 359
# [2024-05-30 16:02:16] replace module (name: net_4_4, op_type: ReLU)
# [2024-05-30 16:02:16] replace module (name: net_4_5, op_type: Linear)
# [2024-05-30 16:02:16] replace linear with new in_features: 359, out_features: 10
# [2024-05-30 16:02:16] Speedup done.
# myVGG(
#   (net): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 45, kernel_size=(3, 3), stride=(1, 1))
#       (1): BatchNorm2d(45, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(45, 45, kernel_size=(3, 3), stride=(1, 1))
#       (1): BatchNorm2d(45, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (2): Sequential(
#       (0): Conv2d(45, 90, kernel_size=(3, 3), stride=(1, 1))
#       (1): BatchNorm2d(90, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (3): Sequential(
#       (0): Conv2d(90, 90, kernel_size=(3, 3), stride=(1, 1))
#       (1): BatchNorm2d(90, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (4): Sequential(
#       (0): Flatten(start_dim=1, end_dim=-1)
#       (1): Linear(in_features=51840, out_features=359, bias=True)
#       (2): ReLU(inplace=True)
#       (3): Linear(in_features=359, out_features=359, bias=True)
#       (4): ReLU(inplace=True)
#       (5): Linear(in_features=359, out_features=10, bias=True)
#     )
#   )
# )
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       2 shape = next(iter(trainloader))[0].shape
#       3 prune_model(model,PRUNING_RATE,shape,device=device)
# ----> 4 train_model(model,n_epochs=EPOCHS,trainloader=trainloader)
#
# File c:\Users\paral\Desktop\work\edge computing\implementations\NeuralNetworkCompressionMethods\shared\models.py:171, in train_model(model, n_epochs, trainloader, optimizer, criterion, device)
#     169 if optimizer is None:
#     170     optimizer = torch.optim.SGD(model.parameters(),lr=0.001, momentum=0.9)
# --> 171 if criterion is None:
#     172     criterion = torch.nn.CrossEntropyLoss()
#     173 for epoch in range(n_epochs):
#
# File c:\Users\paral\Desktop\work\edge computing\implementations\NeuralNetworkCompressionMethods\venv\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\paral\Desktop\work\edge computing\implementations\NeuralNetworkCompressionMethods\venv\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\paral\Desktop\work\edge computing\implementations\NeuralNetworkCompressionMethods\shared\models.py:29, in myVGG.forward(self, x)
#      28 def forward(self, x):
# ---> 29     return self.net(x)
#
# File c:\Users\paral\Desktop\work\edge computing\implementations\NeuralNetworkCompressionMethods\venv\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\paral\Desktop\work\edge computing\implementations\NeuralNetworkCompressionMethods\venv\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\paral\Desktop\work\edge computing\implementations\NeuralNetworkCompressionMethods\venv\Lib\site-packages\torch\nn\modules\container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File c:\Users\paral\Desktop\work\edge computing\implementations\NeuralNetworkCompressionMethods\venv\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\paral\Desktop\work\edge computing\implementations\NeuralNetworkCompressionMethods\venv\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\paral\Desktop\work\edge computing\implementations\NeuralNetworkCompressionMethods\venv\Lib\site-packages\torch\nn\modules\container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File c:\Users\paral\Desktop\work\edge computing\implementations\NeuralNetworkCompressionMethods\venv\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\paral\Desktop\work\edge computing\implementations\NeuralNetworkCompressionMethods\venv\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\paral\Desktop\work\edge computing\implementations\NeuralNetworkCompressionMethods\venv\Lib\site-packages\torch\nn\modules\conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\paral\Desktop\work\edge computing\implementations\NeuralNetworkCompressionMethods\venv\Lib\site-packages\torch\nn\modules\conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
test_model_accuracy(model,testloader,device)
